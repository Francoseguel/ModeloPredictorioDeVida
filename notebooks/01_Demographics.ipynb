# %% [markdown]
# # DEMOGRAPHICS
#
# Carga y visualización de los datasets de demografía.

# %% [markdown]
# > **Datasets en este notebook: 1**
# >
# - `demo_j`

# %%
# %load_ext kedro.ipython
# Out:
# The kedro.ipython extension is already loaded. To reload it, use:
#   %reload_ext kedro.ipython

# %% [markdown]
# ## DEMO_J

# %%
df = catalog.load("demo_j_dataset")
df
# Out:
# [06/08/26 14:24:21] INFO     Loading data from demo_j_dataset (GenericDataset)...              ]8;id=13065202;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=13065203;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\io\data_catalog.py#1053\1053]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#           SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0      93703.0      10.0       2.0       2.0       2.0       NaN       5.0
# 1      93704.0      10.0       2.0       1.0       2.0       NaN       3.0
# 2      93705.0      10.0       2.0       2.0      66.0       NaN       4.0
# 3      93706.0      10.0       2.0       1.0      18.0       NaN       5.0
# 4      93707.0      10.0       2.0       1.0      13.0       NaN       5.0
# ...        ...       ...       ...       ...       ...       ...       ...
# 9249  102952.0      10.0       2.0       2.0      70.0       NaN       5.0
# 9250  102953.0      10.0       2.0       1.0      42.0       NaN       1.0
# 9251  102954.0      10.0       2.0       2.0      41.0       NaN       4.0
# 9252  102955.0      10.0       2.0       2.0      14.0       NaN       4.0
# 9253  102956.0      10.0       2.0       1.0      38.0       NaN       3.0
#
#       RIDRETH3  RIDEXMON  RIDEXAGM  ...  DMDHREDZ  DMDHRMAZ  DMDHSEDZ  \
# 0          6.0       2.0      27.0  ...       3.0       1.0       3.0
# 1          3.0       1.0      33.0  ...       3.0       1.0       2.0
# 2          4.0       2.0       NaN  ...       1.0       2.0       NaN
# 3          6.0       2.0     222.0  ...       3.0       1.0       2.0
# 4          7.0       2.0     158.0  ...       2.0       1.0       3.0
# ...        ...       ...       ...  ...       ...       ...       ...
# 9249       6.0       2.0       NaN  ...       2.0       1.0       1.0
# 9250       1.0       2.0       NaN  ...       2.0       2.0       NaN
# 9251       4.0       1.0       NaN  ...       2.0       2.0       NaN
# 9252       4.0       2.0     175.0  ...       2.0       1.0       2.0
# 9253       3.0       2.0       NaN  ...       2.0       2.0       NaN
#
#           WTINT2YR      WTMEC2YR  SDMVPSU  SDMVSTRA  INDHHIN2  INDFMIN2  \
# 0      9246.491865   8539.731348      2.0     145.0      15.0      15.0
# 1     37338.768343  42566.614750      1.0     143.0      15.0      15.0
# 2      8614.571172   8338.419786      2.0     145.0       3.0       3.0
# 3      8548.632619   8723.439814      2.0     134.0       NaN       NaN
# 4      6769.344567   7064.609730      1.0     138.0      10.0      10.0
# ...            ...           ...      ...       ...       ...       ...
# 9249  16896.276203  18338.711104      2.0     138.0       4.0       4.0
# 9250  61630.380013  63661.951573      2.0     137.0      12.0      12.0
# 9251  17160.895269  17694.783346      1.0     144.0      10.0      10.0
# 9252  14238.445922  14871.839636      1.0     136.0       9.0       9.0
# 9253  38645.740291  39426.299948      1.0     142.0       7.0       7.0
#
#       INDFMPIR
# 0         5.00
# 1         5.00
# 2         0.82
# 3          NaN
# 4         1.88
# ...        ...
# 9249      0.95
# 9250       NaN
# 9251      1.18
# 9252      2.24
# 9253      1.56
#
# [9254 rows x 46 columns]

# %%
print(f"Shape: {df.shape}")
df.head()
# Out:
# Shape: (9254, 46)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0  93703.0      10.0       2.0       2.0       2.0       NaN       5.0
# 1  93704.0      10.0       2.0       1.0       2.0       NaN       3.0
# 2  93705.0      10.0       2.0       2.0      66.0       NaN       4.0
# 3  93706.0      10.0       2.0       1.0      18.0       NaN       5.0
# 4  93707.0      10.0       2.0       1.0      13.0       NaN       5.0
#
#    RIDRETH3  RIDEXMON  RIDEXAGM  ...  DMDHREDZ  DMDHRMAZ  DMDHSEDZ  \
# 0       6.0       2.0      27.0  ...       3.0       1.0       3.0
# 1       3.0       1.0      33.0  ...       3.0       1.0       2.0
# 2       4.0       2.0       NaN  ...       1.0       2.0       NaN
# 3       6.0       2.0     222.0  ...       3.0       1.0       2.0
# 4       7.0       2.0     158.0  ...       2.0       1.0       3.0
#
#        WTINT2YR      WTMEC2YR  SDMVPSU  SDMVSTRA  INDHHIN2  INDFMIN2  INDFMPIR
# 0   9246.491865   8539.731348      2.0     145.0      15.0      15.0      5.00
# 1  37338.768343  42566.614750      1.0     143.0      15.0      15.0      5.00
# 2   8614.571172   8338.419786      2.0     145.0       3.0       3.0      0.82
# 3   8548.632619   8723.439814      2.0     134.0       NaN       NaN       NaN
# 4   6769.344567   7064.609730      1.0     138.0      10.0      10.0      1.88
#
# [5 rows x 46 columns]

# %%
df.tail()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#           SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 9249  102952.0      10.0       2.0       2.0      70.0       NaN       5.0
# 9250  102953.0      10.0       2.0       1.0      42.0       NaN       1.0
# 9251  102954.0      10.0       2.0       2.0      41.0       NaN       4.0
# 9252  102955.0      10.0       2.0       2.0      14.0       NaN       4.0
# 9253  102956.0      10.0       2.0       1.0      38.0       NaN       3.0
#
#       RIDRETH3  RIDEXMON  RIDEXAGM  ...  DMDHREDZ  DMDHRMAZ  DMDHSEDZ  \
# 9249       6.0       2.0       NaN  ...       2.0       1.0       1.0
# 9250       1.0       2.0       NaN  ...       2.0       2.0       NaN
# 9251       4.0       1.0       NaN  ...       2.0       2.0       NaN
# 9252       4.0       2.0     175.0  ...       2.0       1.0       2.0
# 9253       3.0       2.0       NaN  ...       2.0       2.0       NaN
#
#           WTINT2YR      WTMEC2YR  SDMVPSU  SDMVSTRA  INDHHIN2  INDFMIN2  \
# 9249  16896.276203  18338.711104      2.0     138.0       4.0       4.0
# 9250  61630.380013  63661.951573      2.0     137.0      12.0      12.0
# 9251  17160.895269  17694.783346      1.0     144.0      10.0      10.0
# 9252  14238.445922  14871.839636      1.0     136.0       9.0       9.0
# 9253  38645.740291  39426.299948      1.0     142.0       7.0       7.0
#
#       INDFMPIR
# 9249      0.95
# 9250       NaN
# 9251      1.18
# 9252      2.24
# 9253      1.56
#
# [5 rows x 46 columns]

# %%
df.dtypes.to_frame("dtype")
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#             dtype
# SEQN      float64
# SDDSRVYR  float64
# RIDSTATR  float64
# RIAGENDR  float64
# RIDAGEYR  float64
# RIDAGEMN  float64
# RIDRETH1  float64
# RIDRETH3  float64
# RIDEXMON  float64
# RIDEXAGM  float64
# DMQMILIZ  float64
# DMQADFC   float64
# DMDBORN4  float64
# DMDCITZN  float64
# DMDYRSUS  float64
# DMDEDUC3  float64
# DMDEDUC2  float64
# DMDMARTL  float64
# RIDEXPRG  float64
# SIALANG   float64
# SIAPROXY  float64
# SIAINTRP  float64
# FIALANG   float64
# FIAPROXY  float64
# FIAINTRP  float64
# MIALANG   float64
# MIAPROXY  float64
# MIAINTRP  float64
# AIALANGA  float64
# DMDHHSIZ  float64
# DMDFMSIZ  float64
# DMDHHSZA  float64
# DMDHHSZB  float64
# DMDHHSZE  float64
# DMDHRGND  float64
# DMDHRAGZ  float64
# DMDHREDZ  float64
# DMDHRMAZ  float64
# DMDHSEDZ  float64
# WTINT2YR  float64
# WTMEC2YR  float64
# SDMVPSU   float64
# SDMVSTRA  float64
# INDHHIN2  float64
# INDFMIN2  float64
# INDFMPIR  float64

# %%
import pandas as pd
nulls = df.isnull().sum()
null_pct = (nulls / len(df) * 100).round(2)
null_df = pd.DataFrame({"nulos": nulls, "porcentaje (%)": null_pct})
null_df.sort_values("porcentaje (%)", ascending=False)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#           nulos  porcentaje (%)
# DMQADFC    8693           93.94
# RIDAGEMN   8657           93.55
# RIDEXPRG   8144           88.01
# DMDYRSUS   7306           78.95
# DMDEDUC3   6948           75.08
# RIDEXAGM   5821           62.90
# DMDHSEDZ   4503           48.66
# AIALANGA   4277           46.22
# DMDMARTL   3685           39.82
# DMDEDUC2   3685           39.82
# DMQMILIZ   3250           35.12
# MIALANG    2570           27.77
# MIAPROXY   2570           27.77
# MIAINTRP   2570           27.77
# INDFMPIR   1231           13.30
# RIDEXMON    550            5.94
# INDHHIN2    491            5.31
# DMDHREDZ    490            5.30
# INDFMIN2    474            5.12
# FIAINTRP    474            5.12
# FIALANG     474            5.12
# FIAPROXY    474            5.12
# DMDHRMAZ    191            2.06
# DMDCITZN      3            0.03
# RIDRETH3      0            0.00
# SEQN          0            0.00
# SDDSRVYR      0            0.00
# RIDSTATR      0            0.00
# RIAGENDR      0            0.00
# RIDAGEYR      0            0.00
# DMDBORN4      0            0.00
# RIDRETH1      0            0.00
# SIAPROXY      0            0.00
# SIAINTRP      0            0.00
# DMDHHSIZ      0            0.00
# SIALANG       0            0.00
# DMDFMSIZ      0            0.00
# DMDHHSZA      0            0.00
# DMDHRGND      0            0.00
# DMDHRAGZ      0            0.00
# DMDHHSZB      0            0.00
# DMDHHSZE      0            0.00
# SDMVPSU       0            0.00
# WTMEC2YR      0            0.00
# WTINT2YR      0            0.00
# SDMVSTRA      0            0.00

# %%
import matplotlib.pyplot as plt
import math

num_cols = df.select_dtypes(include="number").columns.tolist()
n = len(num_cols)
cols_per_row = 4
rows = math.ceil(n / cols_per_row)
fig, axes = plt.subplots(rows, cols_per_row, figsize=(cols_per_row*4, rows*3))
axes = axes.flatten() if n > 1 else [axes]
for i, col in enumerate(num_cols):
    df[col].dropna().plot(kind="hist", bins=30, ax=axes[i], title=col, color="steelblue", edgecolor="white")
    axes[i].set_xlabel("")
for j in range(len(num_cols), len(axes)):
    axes[j].set_visible(False)
plt.suptitle("Histogramas — variables numéricas", fontsize=14, y=1.01)
plt.tight_layout()
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1600x3600 with 48 Axes>

# %%
num_cols = df.select_dtypes(include="number").columns.tolist()
n = len(num_cols)
cols_per_row = 4
rows = math.ceil(n / cols_per_row)
fig, axes = plt.subplots(rows, cols_per_row, figsize=(cols_per_row*4, rows*3))
axes = axes.flatten() if n > 1 else [axes]
for i, col in enumerate(num_cols):
    df.boxplot(column=col, ax=axes[i])
    axes[i].set_title(col)
for j in range(len(num_cols), len(axes)):
    axes[j].set_visible(False)
plt.suptitle("Boxplots — detección de outliers", fontsize=14, y=1.01)
plt.tight_layout()
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1600x3600 with 48 Axes>
