# %% [markdown]
# # DIETARY
#
# Carga y visualizacion de los datasets dieteticos.

# %%
# %load_ext kedro.ipython
# Out:
# [06/05/26 14:52:48] INFO     Using                                                                  ]8;id=14515732;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\framework\project\__init__.py\__init__.py]8;;\:]8;id=14515733;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\framework\project\__init__.py#281\281]8;;\
#                              'C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages
#                              \kedro\framework\project\rich_logging.yml' as logging configuration.
# [06/05/26 14:52:49] INFO     Registered line magic '%reload_kedro'                                   ]8;id=14515740;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=14515741;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\ipython\__init__.py#67\67]8;;\
# ...

# %% [markdown]
# ## DR1TOT_J (Total Nutrient Intakes - Day 1)

# %%
df = catalog.load("dr1tot_j_dataset")
df
# Out:
#                     INFO     Loading data from dr1tot_j_dataset (GenericDataset)...            ]8;id=14515792;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=14515793;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\io\data_catalog.py#1053\1053]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#           SEQN        WTDRD1        WTDR2D  DR1DRSTZ  DR1EXMER  DRABF  DRDINT  \
# 0      93703.0  5.397605e-79           NaN       5.0       NaN    NaN     NaN
# 1      93704.0  8.171401e+04  8.244287e+04       1.0      49.0    2.0     2.0
# 2      93705.0  7.185561e+03  5.640391e+03       1.0      73.0    2.0     2.0
# 3      93706.0  6.463883e+03  5.397605e-79       1.0      86.0    2.0     1.0
# 4      93707.0  1.533378e+04  2.270707e+04       1.0      81.0    2.0     2.0
# ...

# %%
print(f"Shape: {df.shape}")
df.head()

# %%
df.tail()

# %%
df.dtypes.to_frame("dtype")

# %%
import pandas as pd
nulls = df.isnull().sum()
null_pct = (nulls / len(df) * 100).round(2)
null_df = pd.DataFrame({"nulos": nulls, "porcentaje (%)": null_pct})
null_df.sort_values("porcentaje (%)", ascending=False)

# %% [markdown]
# ## DR2TOT_J (Total Nutrient Intakes - Day 2)

# %%
df = catalog.load("dr2tot_j_dataset")
df
# Out:
# [06/05/26 14:52:51] INFO     Loading data from dr2tot_j_dataset (GenericDataset)...            ]8;id=14515798;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=14515799;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\io\data_catalog.py#1053\1053]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#           SEQN        WTDRD1        WTDR2D  DR2DRSTZ  DR2EXMER  DRABF  DRDINT  \
# 0      93703.0  5.397605e-79           NaN       5.0       NaN    NaN     NaN
# 1      93704.0  8.171401e+04  8.244287e+04       1.0      87.0    2.0     2.0
# 2      93705.0  7.185561e+03  5.640391e+03       1.0      91.0    2.0     2.0
# 3      93706.0  6.463883e+03  5.397605e-79       5.0       NaN    2.0     1.0
# 4      93707.0  1.533378e+04  2.270707e+04       1.0      78.0    2.0     2.0
# ...

# %%
print(f"Shape: {df.shape}")
df.head()

# %%
df.tail()

# %%
df.dtypes.to_frame("dtype")

# %%
import pandas as pd
nulls = df.isnull().sum()
null_pct = (nulls / len(df) * 100).round(2)
null_df = pd.DataFrame({"nulos": nulls, "porcentaje (%)": null_pct})
null_df.sort_values("porcentaje (%)", ascending=False)
