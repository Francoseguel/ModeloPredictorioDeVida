# %% [markdown]
# # EXAMINATION
#
# Carga y visualización de los datasets de examen físico.

# %% [markdown]
# > **Datasets en este notebook: 2**
# >
# - `bmx_j`
# - `bpxo_j`

# %%
# %load_ext kedro.ipython
# Out:
# [06/05/26 14:46:59] INFO     Using                                                                  ]8;id=9562908;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\framework\project\__init__.py\__init__.py]8;;\:]8;id=9562909;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\framework\project\__init__.py#281\281]8;;\
#                              'C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages
#                              \kedro\framework\project\rich_logging.yml' as logging configuration.
#                     INFO     Registered line magic '%reload_kedro'                                   ]8;id=9562916;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=9562917;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\ipython\__init__.py#67\67]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=9562923;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=9562924;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\ipython\__init__.py#69\69]8;;\
#                     INFO     Resolved project path as:                                              ]8;id=9562930;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=9562931;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\ipython\__init__.py#193\193]8;;\
#                              C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes.
#                              To set a different path, run '%reload_kedro <project_root>'
# [06/05/26 14:47:00] INFO     No typed parameter requirements found, returning original   ]8;id=9562938;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\validation\parameter_validator.py\parameter_validator.py]8;;\:]8;id=9562939;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\validation\parameter_validator.py#124\124]8;;\
#                              parameters
#                     INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=9562946;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro_telemetry\plugin.py\plugin.py]8;;\:]8;id=9562947;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro_telemetry\plugin.py#273\273]8;;\
#                              the product. No personal data or IP addresses are stored on our side. To
#                              opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK` environment
#                              variables, or create a `.telemetry` file in the current working
#                              directory with the contents `consent: false`. To hide this message,
#                              explicitly grant or deny consent. Read more at
#                              https://docs.kedro.org/en/stable/about/telemetry/
# [06/05/26 14:47:01] INFO     Kedro project Nhanes                                                   ]8;id=9562953;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=9562954;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\ipython\__init__.py#159\159]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=9562960;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=9562961;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\ipython\__init__.py#160\160]8;;\
#                              'pipelines'

# %% [markdown]
# ## BMX_J (Body Measures)

# %%
df = catalog.load("bmx_j_dataset")
df
# Out:
#                     INFO     Loading data from bmx_j_dataset (GenericDataset)...               ]8;id=9562968;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=9562969;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\io\data_catalog.py#1053\1053]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#           SEQN  BMDSTATS  BMXWT  BMIWT  BMXRECUM  BMIRECUM  BMXHEAD  BMIHEAD  \
# 0      93703.0       1.0   13.7    3.0      89.6       NaN      NaN      NaN
# 1      93704.0       1.0   13.9    NaN      95.0       NaN      NaN      NaN
# 2      93705.0       1.0   79.5    NaN       NaN       NaN      NaN      NaN
# 3      93706.0       1.0   66.3    NaN       NaN       NaN      NaN      NaN
# 4      93707.0       1.0   45.4    NaN       NaN       NaN      NaN      NaN
# ...        ...       ...    ...    ...       ...       ...      ...      ...
# 8699  102952.0       1.0   49.0    NaN       NaN       NaN      NaN      NaN
# 8700  102953.0       1.0   97.4    NaN       NaN       NaN      NaN      NaN
# 8701  102954.0       1.0   69.1    NaN       NaN       NaN      NaN      NaN
# 8702  102955.0       1.0  111.9    NaN       NaN       NaN      NaN      NaN
# 8703  102956.0       1.0  111.5    NaN       NaN       NaN      NaN      NaN
#
#       BMXHT  BMIHT  ...  BMXLEG  BMILEG  BMXARML  BMIARML  BMXARMC  BMIARMC  \
# 0      88.6    NaN  ...     NaN     NaN     18.0      NaN     16.2      NaN
# 1      94.2    NaN  ...     NaN     NaN     18.6      NaN     15.2      NaN
# 2     158.3    NaN  ...    37.0     NaN     36.0      NaN     32.0      NaN
# 3     175.7    NaN  ...    46.6     NaN     38.8      NaN     27.0      NaN
# 4     158.4    NaN  ...    38.1     NaN     33.8      NaN     21.5      NaN
# ...     ...    ...  ...     ...     ...      ...      ...      ...      ...
# 8699  156.5    NaN  ...    34.4     NaN     32.6      NaN     25.1      NaN
# 8700  164.9    NaN  ...    38.2     NaN     36.6      NaN     40.6      NaN
# 8701  162.6    NaN  ...    39.2     NaN     35.2      NaN     26.8      NaN
# 8702  156.6    NaN  ...    39.2     NaN     35.0      NaN     44.5      NaN
# 8703  175.8    NaN  ...    42.5     NaN     38.0      NaN     40.0      NaN
#
#       BMXWAIST  BMIWAIST  BMXHIP  BMIHIP
# 0         48.2       NaN     NaN     NaN
# 1         50.0       NaN     NaN     NaN
# 2        101.8       NaN   110.0     NaN
# 3         79.3       NaN    94.4     NaN
# 4         64.1       NaN    83.0     NaN
# ...        ...       ...     ...     ...
# 8699      82.2       NaN    87.3     NaN
# 8700     114.8       NaN   112.8     NaN
# 8701      86.4       NaN   102.7     NaN
# 8702     113.5       NaN   128.3     NaN
# 8703     122.0       NaN   110.0     NaN
#
# [8704 rows x 21 columns]

# %%
print(f"Shape: {df.shape}")
df.head()

# %%
df.tail()

# %%
df.dtypes.to_frame("dtype")

# %%
import pandas as pd
nulls = df.isnull().sum()
null_pct = (nulls / len(df) * 100).round(2)
null_df = pd.DataFrame({"nulos": nulls, "porcentaje (%)": null_pct})
null_df.sort_values("porcentaje (%)", ascending=False)

# %%
import matplotlib.pyplot as plt
import math

num_cols = df.select_dtypes(include="number").columns.tolist()
n = len(num_cols)
cols_per_row = 4
rows = math.ceil(n / cols_per_row)
fig, axes = plt.subplots(rows, cols_per_row, figsize=(cols_per_row*4, rows*3))
axes = axes.flatten() if n > 1 else [axes]
for i, col in enumerate(num_cols):
    df[col].dropna().plot(kind="hist", bins=30, ax=axes[i], title=col, color="steelblue", edgecolor="white")
    axes[i].set_xlabel("")
for j in range(len(num_cols), len(axes)):
    axes[j].set_visible(False)
plt.suptitle("Histogramas — variables numéricas", fontsize=14, y=1.01)
plt.tight_layout()
plt.show()

# %%
num_cols = df.select_dtypes(include="number").columns.tolist()
n = len(num_cols)
cols_per_row = 4
rows = math.ceil(n / cols_per_row)
fig, axes = plt.subplots(rows, cols_per_row, figsize=(cols_per_row*4, rows*3))
axes = axes.flatten() if n > 1 else [axes]
for i, col in enumerate(num_cols):
    df.boxplot(column=col, ax=axes[i])
    axes[i].set_title(col)
for j in range(len(num_cols), len(axes)):
    axes[j].set_visible(False)
plt.suptitle("Boxplots — detección de outliers", fontsize=14, y=1.01)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## BPXO_J (Blood Pressure - Oscillometric)

# %%
df = catalog.load("bpxo_j_dataset")
df
# Out:
#                     INFO     Loading data from bpxo_j_dataset (GenericDataset)...              ]8;id=9562974;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=9562975;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\io\data_catalog.py#1053\1053]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#           SEQN BPAOARM  BPAOCSZ  BPAOMNTS  BPXOSY1  BPXODI1  BPXOSY2  BPXODI2  \
# 0      93705.0    b'R'      4.0     -20.0    164.0     66.0    165.0     66.0
# 1      93706.0    b'R'      3.0     138.0    126.0     74.0    128.0     68.0
# 2      93707.0    b'R'      2.0      12.0    136.0     71.0    133.0     72.0
# 3      93708.0    b'R'      3.0      22.0    146.0     82.0    142.0     76.0
# 4      93709.0    b'R'      4.0      58.0    120.0     83.0    124.0     81.0
# ...        ...     ...      ...       ...      ...      ...      ...      ...
# 7127  102952.0    b'R'      3.0      97.0    154.0     92.0    144.0     84.0
# 7128  102953.0    b'R'      4.0     -57.0    135.0     91.0    133.0     86.0
# 7129  102954.0     b''      3.0    -101.0    123.0     75.0    119.0     71.0
# 7130  102955.0    b'R'      5.0     -88.0     92.0     64.0     97.0     64.0
# 7131  102956.0    b'R'      4.0      30.0    143.0    100.0    146.0    101.0
#
#       BPXOSY3  BPXODI3  BPXOPLS1  BPXOPLS2  BPXOPLS3
# 0       172.0     66.0      52.0      51.0      49.0
# 1       133.0     71.0      76.0      83.0      73.0
# 2       139.0     71.0     100.0      89.0      91.0
# 3       151.0     81.0      67.0      65.0      71.0
# 4       113.0     74.0      64.0      62.0      61.0
# ...       ...      ...       ...       ...       ...
# 7127    145.0     69.0      88.0      84.0      74.0
# 7128    132.0     83.0      76.0      79.0      78.0
# 7129    122.0     73.0       NaN       NaN       NaN
# 7130     94.0     63.0      71.0      71.0      76.0
# 7131    145.0    103.0      72.0      74.0      75.0
#
# [7132 rows x 13 columns]

# %%
print(f"Shape: {df.shape}")
df.head()

# %%
df.tail()

# %%
df.dtypes.to_frame("dtype")

# %%
import pandas as pd
nulls = df.isnull().sum()
null_pct = (nulls / len(df) * 100).round(2)
null_df = pd.DataFrame({"nulos": nulls, "porcentaje (%)": null_pct})
null_df.sort_values("porcentaje (%)", ascending=False)

# %%
import matplotlib.pyplot as plt
import math

num_cols = df.select_dtypes(include="number").columns.tolist()
n = len(num_cols)
cols_per_row = 4
rows = math.ceil(n / cols_per_row)
fig, axes = plt.subplots(rows, cols_per_row, figsize=(cols_per_row*4, rows*3))
axes = axes.flatten() if n > 1 else [axes]
for i, col in enumerate(num_cols):
    df[col].dropna().plot(kind="hist", bins=30, ax=axes[i], title=col, color="steelblue", edgecolor="white")
    axes[i].set_xlabel("")
for j in range(len(num_cols), len(axes)):
    axes[j].set_visible(False)
plt.suptitle("Histogramas — variables numéricas", fontsize=14, y=1.01)
plt.tight_layout()
plt.show()

# %%
num_cols = df.select_dtypes(include="number").columns.tolist()
n = len(num_cols)
cols_per_row = 4
rows = math.ceil(n / cols_per_row)
fig, axes = plt.subplots(rows, cols_per_row, figsize=(cols_per_row*4, rows*3))
axes = axes.flatten() if n > 1 else [axes]
for i, col in enumerate(num_cols):
    df.boxplot(column=col, ax=axes[i])
    axes[i].set_title(col)
for j in range(len(num_cols), len(axes)):
    axes[j].set_visible(False)
plt.suptitle("Boxplots — detección de outliers", fontsize=14, y=1.01)
plt.tight_layout()
plt.show()
