# %%
# %load_ext kedro.ipython

# %%
import pandas as pd

# %% [markdown]
# ## Dietary Interview - Individual Foods (Day 1) — DR1IFF_J

# %%
dr1iff = catalog.load("dr1iff_j_dataset")
dr1iff.head()

# %% [markdown]
# ## Dietary Interview - Total Nutrient Intakes (Day 1) — DR1TOT_J

# %%
dr1tot = catalog.load("dr1tot_j_dataset")
dr1tot.head()

# %% [markdown]
# ## Dietary Interview - Individual Foods (Day 2) — DR2IFF_J

# %%
dr2iff = catalog.load("dr2iff_j_dataset")
dr2iff.head()

# %% [markdown]
# ## Dietary Interview - Total Nutrient Intakes (Day 2) — DR2TOT_J

# %%
dr2tot = catalog.load("dr2tot_j_dataset")
dr2tot.head()

# %% [markdown]
# ## Dietary Interview - Food Codes — DRXFCD_J

# %%
drxfcd = catalog.load("drxfcd_j_dataset")
drxfcd.head()

# %% [markdown]
# ## Dietary Supplement Use - Individual (Day 1) — DS1IDS_J

# %%
ds1ids = catalog.load("ds1ids_j_dataset")
ds1ids.head()

# %% [markdown]
# ## Dietary Supplement Use - Total (Day 1) — DS1TOT_J

# %%
ds1tot = catalog.load("ds1tot_j_dataset")
ds1tot.head()

# %% [markdown]
# ## Dietary Supplement Use - Individual (Day 2) — DS2IDS_J

# %%
ds2ids = catalog.load("ds2ids_j_dataset")
ds2ids.head()

# %% [markdown]
# ## Dietary Supplement Use - Total (Day 2) — DS2TOT_J

# %%
ds2tot = catalog.load("ds2tot_j_dataset")
ds2tot.head()

# %% [markdown]
# ## Dietary Supplement Database - Blend Products — DSBI

# %%
dsbi = catalog.load("dsbi_dataset")
dsbi.head()

# %% [markdown]
# ## Dietary Supplement Database - Ingredient Information — DSII

# %%
dsii = catalog.load("dsii_dataset")
dsii.head()

# %% [markdown]
# ## Dietary Supplement Database - Product Information — DSPI

# %%
dspi = catalog.load("dspi_dataset")
dspi.head()

# %% [markdown]
# ## Dietary Supplement Use - 30 Day - Individual — DSQIDS_J

# %%
dsqids = catalog.load("dsqids_j_dataset")
dsqids.head()

# %% [markdown]
# ## Dietary Supplement Use - 30 Day - Total — DSQTOT_J

# %%
dsqtot = catalog.load("dsqtot_j_dataset")
dsqtot.head()
