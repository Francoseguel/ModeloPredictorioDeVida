# %%
# %load_ext kedro.ipython

# %%
import pandas as pd

# %% [markdown]
# ## Audiometry — AUX_J

# %%
aux = catalog.load("aux_j_dataset")
aux.head()
# Out:
# [06/01/26 16:11:21] INFO     Loading data from aux_j_dataset (GenericDataset)...               ]8;id=3103598;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=3103599;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\io\data_catalog.py#1053\1053]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       SEQN  AUAEXSTS  AUAEXCMT  AUQ011  AUQ540  AUQ550  AUQ550A  AUQ550B  \
# 0  93706.0       2.0       4.0     NaN     NaN     NaN      NaN      NaN
# 1  93707.0       1.0       NaN     NaN     NaN     NaN      NaN      NaN
# 2  93709.0       1.0       NaN     NaN     NaN     NaN      NaN      NaN
# 3  93712.0       1.0       NaN     NaN     NaN     NaN      NaN      NaN
# 4  93715.0       1.0       NaN     NaN     NaN     NaN      NaN      NaN
#
# ...

# %% [markdown]
# ## Audiometry - Acoustic Reflex — AUXAR_J

# %%
auxar = catalog.load("auxar_j_dataset")
auxar.head()

# %% [markdown]
# ## Audiometry - Tympanometry — AUXTYM_J

# %%
auxtym = catalog.load("auxtym_j_dataset")
auxtym.head()

# %% [markdown]
# ## Audiometry - Wideband Reflectance — AUXWBR_J

# %%
auxwbr = catalog.load("auxwbr_j_dataset")
auxwbr.head()

# %% [markdown]
# ## Body Measures — BMX_J

# %%
bmx = catalog.load("bmx_j_dataset")
bmx.head()

# %% [markdown]
# ## Blood Pressure — BPX_J

# %%
bpx = catalog.load("bpx_j_dataset")
bpx.head()

# %% [markdown]
# ## Blood Pressure - Oscillometric — BPXO_J

# %%
bpxo = catalog.load("bpxo_j_dataset")
bpxo.head()

# %% [markdown]
# ## DXA - Whole Body — DXX_J

# %%
dxx = catalog.load("dxx_j_dataset")
dxx.head()

# %% [markdown]
# ## DXA - Android/Gynoid — DXXAG_J

# %%
dxxag = catalog.load("dxxag_j_dataset")
dxxag.head()

# %% [markdown]
# ## DXA - Femur — DXXFEM_J

# %%
dxxfem = catalog.load("dxxfem_j_dataset")
dxxfem.head()

# %% [markdown]
# ## DXA - Spine — DXXSPN_J

# %%
dxxspn = catalog.load("dxxspn_j_dataset")
dxxspn.head()

# %% [markdown]
# ## Oral Health - Dentition — OHXDEN_J

# %%
ohxden = catalog.load("ohxden_j_dataset")
ohxden.head()

# %% [markdown]
# ## Oral Health - Recommendation of Care — OHXREF_J

# %%
ohxref = catalog.load("ohxref_j_dataset")
ohxref.head()
# Out:
# [06/01/26 16:11:37] INFO     Loading data from ohxref_j_dataset (GenericDataset)...            ]8;id=3103604;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=3103605;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\io\data_catalog.py#1053\1053]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       SEQN  OHDEXSTS  OHDRCSTS  OHAREC  OHAROCDT  OHAROCGP  OHAROCOH  \
# 0  93703.0       1.0       1.0     4.0       NaN       NaN       NaN
# 1  93704.0       1.0       1.0     4.0       NaN       NaN       NaN
# 2  93705.0       1.0       1.0     4.0       NaN       NaN       NaN
# 3  93706.0       1.0       1.0     4.0       NaN       NaN       NaN
# 4  93707.0       1.0       1.0     4.0       NaN       NaN       NaN
#
#    OHAROCCI  OHAROCDE  OHARNF  OHAROTH  OHAPOS
# ...
