# %%
# %load_ext kedro.ipython
# Out:
# The kedro.ipython extension is already loaded. To reload it, use:
#   %reload_ext kedro.ipython

# %%
import pandas as pd

# %% [markdown]
# ## Albumin & Creatinine - Urine — ALB_CR_J

# %%
alb_cr = catalog.load("alb_cr_j_dataset")
alb_cr.head()
# Out:
# [06/01/26 16:12:05] INFO     Loading data from alb_cr_j_dataset (GenericDataset)...            ]8;id=14201119;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=14201120;file://C:\Users\Felipe\Desktop\NHANES_PROJECT\nhanes\.venv\Lib\site-packages\kedro\io\data_catalog.py#1053\1053]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       SEQN  URXUMA  URXUMS      URDUMALC  URXUCR   URXCRS      URDUCRLC  \
# 0  93705.0     3.2     3.2  5.397605e-79    24.0   2121.6  5.397605e-79
# 1  93706.0    39.6    39.6  5.397605e-79    69.0   6099.6  5.397605e-79
# 2  93707.0    41.6    41.6  5.397605e-79   209.0  18475.6  5.397605e-79
# 3  93708.0     9.1     9.1  5.397605e-79    47.0   4154.8  5.397605e-79
# 4  93709.0    26.4    26.4  5.397605e-79   215.0  19006.0  5.397605e-79
#
#    URDACT
# 0   13.33
# 1   57.39
# ...

# %% [markdown]
# ## Standard Biochemistry Profile — BIOPRO_J

# %%
biopro = catalog.load("biopro_j_dataset")
biopro.head()

# %% [markdown]
# ## Complete Blood Count - 5-Part Differential — CBC_J

# %%
cbc = catalog.load("cbc_j_dataset")
cbc.head()

# %% [markdown]
# ## Cytomegalovirus IgG & IgM Antibodies - Serum — CMV_J

# %%
cmv = catalog.load("cmv_j_dataset")
cmv.head()

# %% [markdown]
# ## Cotinine & Hydroxycotinine - Serum — COT_J

# %%
cot = catalog.load("cot_j_dataset")
cot.head()

# %% [markdown]
# ## Chromium & Cobalt - Urine — CRCO_J

# %%
crco = catalog.load("crco_j_dataset")
crco.head()

# %% [markdown]
# ## Environmental Phenols & Parabens - Urine — EPHPP_J

# %%
ephpp = catalog.load("ephpp_j_dataset")
ephpp.head()

# %% [markdown]
# ## Ethylene Oxide - Blood — ETHOX_J

# %%
ethox = catalog.load("ethox_j_dataset")
ethox.head()

# %% [markdown]
# ## Fasting Questionnaire — FASTQX_J

# %%
fastqx = catalog.load("fastqx_j_dataset")
fastqx.head()

# %% [markdown]
# ## Ferritin - Serum — FERTIN_J

# %%
fertin = catalog.load("fertin_j_dataset")
fertin.head()

# %% [markdown]
# ## Iron Status - Serum (Fe, TIBC, Transferrin Saturation) — FETIB_J

# %%
fetib = catalog.load("fetib_j_dataset")
fetib.head()

# %% [markdown]
# ## Folate - RBC & Serum — FOLATE_J

# %%
folate = catalog.load("folate_j_dataset")
folate.head()

# %% [markdown]
# ## Folate Forms - Total & Individual - Serum — FOLFMS_J

# %%
folfms = catalog.load("folfms_j_dataset")
folfms.head()

# %% [markdown]
# ## Fluoride - Plasma — FR_J

# %%
fr = catalog.load("fr_j_dataset")
fr.head()

# %% [markdown]
# ## Glycohemoglobin (HbA1c) — GHB_J

# %%
ghb = catalog.load("ghb_j_dataset")
ghb.head()

# %% [markdown]
# ## Plasma Fasting Glucose — GLU_J

# %%
glu = catalog.load("glu_j_dataset")
glu.head()

# %% [markdown]
# ## HDL Cholesterol — HDL_J

# %%
hdl = catalog.load("hdl_j_dataset")
hdl.head()

# %% [markdown]
# ## Hepatitis A Antibody — HEPA_J

# %%
hepa = catalog.load("hepa_j_dataset")
hepa.head()

# %% [markdown]
# ## Hepatitis B: Core Antibody, Surface Antigen & Hepatitis D — HEPBD_J

# %%
hepbd = catalog.load("hepbd_j_dataset")
hepbd.head()

# %% [markdown]
# ## Hepatitis B: Surface Antibody — HEPB_S_J

# %%
hepb_s = catalog.load("hepb_s_j_dataset")
hepb_s.head()

# %% [markdown]
# ## Hepatitis C — HEPC_J

# %%
hepc = catalog.load("hepc_j_dataset")
hepc.head()

# %% [markdown]
# ## Hepatitis E — HEPE_J

# %%
hepe = catalog.load("hepe_j_dataset")
hepe.head()

# %% [markdown]
# ## HIV Antibody Test — HIV_J

# %%
hiv = catalog.load("hiv_j_dataset")
hiv.head()

# %% [markdown]
# ## High-Sensitivity C-Reactive Protein — HSCRP_J

# %%
hscrp = catalog.load("hscrp_j_dataset")
hscrp.head()

# %% [markdown]
# ## Mercury: Inorganic & Ethyl - Blood — IHGEM_J

# %%
ihgem = catalog.load("ihgem_j_dataset")
ihgem.head()

# %% [markdown]
# ## Insulin - Serum — INS_J

# %%
ins = catalog.load("ins_j_dataset")
ins.head()

# %% [markdown]
# ## Organophosphate Insecticides - Dialkyl Phosphate Metabolites - Urine — OPD_J

# %%
opd = catalog.load("opd_j_dataset")
opd.head()

# %% [markdown]
# ## Polycyclic Aromatic Hydrocarbons (PAH) - Urine — PAH_J

# %%
pah = catalog.load("pah_j_dataset")
pah.head()

# %% [markdown]
# ## Lead, Cadmium, Total Mercury, Selenium & Manganese - Blood — PBCD_J

# %%
pbcd = catalog.load("pbcd_j_dataset")
pbcd.head()

# %% [markdown]
# ## Perchlorate, Nitrate & Thiocyanate - Urine — PERNT_J

# %%
pernt = catalog.load("pernt_j_dataset")
pernt.head()

# %% [markdown]
# ## Per- and Polyfluoroalkyl Substances (PFAS) - Serum — PFAS_J

# %%
pfas = catalog.load("pfas_j_dataset")
pfas.head()

# %% [markdown]
# ## Phthalates & Plasticizers Metabolites - Urine — PHTHTE_J

# %%
phthte = catalog.load("phthte_j_dataset")
phthte.head()

# %% [markdown]
# ## Alpha-1-Acid Glycoprotein (AGP) - Serum (Surplus) — SSAGP_J

# %%
ssagp = catalog.load("ssagp_j_dataset")
ssagp.head()

# %% [markdown]
# ## Flame Retardants - Urine (Surplus) — SSFR_J

# %%
ssfr = catalog.load("ssfr_j_dataset")
ssfr.head()

# %% [markdown]
# ## Glyphosate - Urine (Surplus) — SSGLYP_J

# %%
ssglyp = catalog.load("ssglyp_j_dataset")
ssglyp.head()

# %% [markdown]
# ## Neonicotinoids & Metabolites - Urine (Surplus) — SSNEON_J

# %%
ssneon = catalog.load("ssneon_j_dataset")
ssneon.head()

# %% [markdown]
# ## PFAS - Serum (Surplus) — SSPFAS_J

# %%
sspfas = catalog.load("sspfas_j_dataset")
sspfas.head()

# %% [markdown]
# ## Testosterone - Serum (Surplus) — SSTST_J

# %%
sstst = catalog.load("sstst_j_dataset")
sstst.head()

# %% [markdown]
# ## Volatile Compounds - Blood (Surplus) — SSUVCM_J

# %%
ssuvcm = catalog.load("ssuvcm_j_dataset")
ssuvcm.head()

# %% [markdown]
# ## Volatile Organic Compounds - Urine (Surplus) — SSUVOC_J

# %%
ssuvoc = catalog.load("ssuvoc_j_dataset")
ssuvoc.head()

# %% [markdown]
# ## Total Cholesterol — TCHOL_J

# %%
tchol = catalog.load("tchol_j_dataset")
tchol.head()

# %% [markdown]
# ## Transferrin Receptor — TFR_J

# %%
tfr = catalog.load("tfr_j_dataset")
tfr.head()

# %% [markdown]
# ## Triglycerides & LDL Cholesterol — TRIGLY_J

# %%
trigly = catalog.load("trigly_j_dataset")
trigly.head()

# %% [markdown]
# ## Urinary Arsenics — UAS_J

# %%
uas = catalog.load("uas_j_dataset")
uas.head()

# %% [markdown]
# ## Urine Flow Rate — UCFLOW_J

# %%
ucflow = catalog.load("ucflow_j_dataset")
ucflow.head()

# %% [markdown]
# ## Urinary Chromium & Cobalt — UCM_J

# %%
ucm = catalog.load("ucm_j_dataset")
ucm.head()

# %% [markdown]
# ## Cotinine & Hydroxycotinine - Urine — UCOT_J

# %%
ucot = catalog.load("ucot_j_dataset")
ucot.head()

# %% [markdown]
# ## Urine Pregnancy Test — UCPREG_J

# %%
ucpreg = catalog.load("ucpreg_j_dataset")
ucpreg.head()

# %% [markdown]
# ## Urinary Mercury — UHG_J

# %%
uhg = catalog.load("uhg_j_dataset")
uhg.head()

# %% [markdown]
# ## Urinary Iodine — UIO_J

# %%
uio = catalog.load("uio_j_dataset")
uio.head()

# %% [markdown]
# ## Urinary Metals — UM_J

# %%
um = catalog.load("um_j_dataset")
um.head()

# %% [markdown]
# ## Urinary Nickel & Vanadium — UNI_J

# %%
uni = catalog.load("uni_j_dataset")
uni.head()

# %% [markdown]
# ## Organophosphate Insecticides - Urinary Metabolites — UPHOPM_J

# %%
uphopm = catalog.load("uphopm_j_dataset")
uphopm.head()

# %% [markdown]
# ## Urinary Total Arsenic — UTAS_J

# %%
utas = catalog.load("utas_j_dataset")
utas.head()

# %% [markdown]
# ## Volatile Organic Compounds - Urine — UVOC_J

# %%
uvoc = catalog.load("uvoc_j_dataset")
uvoc.head()

# %% [markdown]
# ## Vitamin C - Serum — VIC_J

# %%
vic = catalog.load("vic_j_dataset")
vic.head()

# %% [markdown]
# ## Vitamin D (25-Hydroxyvitamin D) — VID_J

# %%
vid = catalog.load("vid_j_dataset")
vid.head()

# %% [markdown]
# ## Vitamin A, Vitamin E & Carotenoids — VITAEC_J

# %%
vitaec = catalog.load("vitaec_j_dataset")
vitaec.head()

# %% [markdown]
# ## Volatile Organic Compounds - Blood — VOCWB_J

# %%
vocwb = catalog.load("vocwb_j_dataset")
vocwb.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 vocwb = catalog.load("vocwb_j_dataset")
#       2 vocwb.head()
#
# NameError: name 'catalog' is not defined
