# %%
# %load_ext kedro.ipython

# %%
import pandas as pd

# %% [markdown]
# ## Acculturation — ACQ_J

# %%
acq = catalog.load("acq_j_dataset")
acq.head()

# %% [markdown]
# ## Alcohol Use — ALQ_J

# %%
alq = catalog.load("alq_j_dataset")
alq.head()

# %% [markdown]
# ## Audiometry (Questionnaire) — AUQ_J

# %%
auq = catalog.load("auq_j_dataset")
auq.head()

# %% [markdown]
# ## Blood Pressure & Cholesterol — BPQ_J

# %%
bpq = catalog.load("bpq_j_dataset")
bpq.head()

# %% [markdown]
# ## Consumer Behavior Phone Follow-up - Adult — CBQPFA_J

# %%
cbqpfa = catalog.load("cbqpfa_j_dataset")
cbqpfa.head()

# %% [markdown]
# ## Consumer Behavior Phone Follow-up - Child — CBQPFC_J

# %%
cbqpfc = catalog.load("cbqpfc_j_dataset")
cbqpfc.head()

# %% [markdown]
# ## Consumer Behavior — CBQ_J

# %%
cbq = catalog.load("cbq_j_dataset")
cbq.head()

# %% [markdown]
# ## Cardiovascular Health — CDQ_J

# %%
cdq = catalog.load("cdq_j_dataset")
cdq.head()

# %% [markdown]
# ## Diet Behavior & Nutrition — DBQ_J

# %%
dbq = catalog.load("dbq_j_dataset")
dbq.head()

# %% [markdown]
# ## Dermatology — DEQ_J

# %%
deq = catalog.load("deq_j_dataset")
deq.head()

# %% [markdown]
# ## Diabetes — DIQ_J

# %%
diq = catalog.load("diq_j_dataset")
diq.head()

# %% [markdown]
# ## Disability — DLQ_J

# %%
dlq = catalog.load("dlq_j_dataset")
dlq.head()

# %% [markdown]
# ## Mental Health - Depression Screener (PHQ-9) — DPQ_J

# %%
dpq = catalog.load("dpq_j_dataset")
dpq.head()

# %% [markdown]
# ## Drug Use — DUQ_J

# %%
duq = catalog.load("duq_j_dataset")
duq.head()

# %% [markdown]
# ## Early Childhood — ECQ_J

# %%
ecq = catalog.load("ecq_j_dataset")
ecq.head()

# %% [markdown]
# ## Food Security — FSQ_J

# %%
fsq = catalog.load("fsq_j_dataset")
fsq.head()

# %% [markdown]
# ## Hepatitis (Questionnaire) — HEQ_J

# %%
heq = catalog.load("heq_j_dataset")
heq.head()

# %% [markdown]
# ## Health Insurance — HIQ_J

# %%
hiq = catalog.load("hiq_j_dataset")
hiq.head()

# %% [markdown]
# ## Housing Characteristics — HOQ_J

# %%
hoq = catalog.load("hoq_j_dataset")
hoq.head()

# %% [markdown]
# ## Current Health Status — HSQ_J

# %%
hsq = catalog.load("hsq_j_dataset")
hsq.head()

# %% [markdown]
# ## Hospital Utilization & Access to Care — HUQ_J

# %%
huq = catalog.load("huq_j_dataset")
huq.head()

# %% [markdown]
# ## Immunization — IMQ_J

# %%
imq = catalog.load("imq_j_dataset")
imq.head()

# %% [markdown]
# ## Income — INQ_J

# %%
inq = catalog.load("inq_j_dataset")
inq.head()

# %% [markdown]
# ## Kidney Conditions - Urology — KIQ_U_J

# %%
kiq_u = catalog.load("kiq_u_j_dataset")
kiq_u.head()

# %% [markdown]
# ## Medical Conditions — MCQ_J

# %%
mcq = catalog.load("mcq_j_dataset")
mcq.head()

# %% [markdown]
# ## Occupation — OCQ_J

# %%
ocq = catalog.load("ocq_j_dataset")
ocq.head()

# %% [markdown]
# ## Oral Health (Questionnaire) — OHQ_J

# %%
ohq = catalog.load("ohq_j_dataset")
ohq.head()

# %% [markdown]
# ## Osteoporosis — OSQ_J

# %%
osq = catalog.load("osq_j_dataset")
osq.head()

# %% [markdown]
# ## Physical Activity — PAQ_J

# %%
paq = catalog.load("paq_j_dataset")
paq.head()

# %% [markdown]
# ## Physical Activity - Youth — PAQY_J

# %%
paqy = catalog.load("paqy_j_dataset")
paqy.head()

# %% [markdown]
# ## Physical Functioning — PFQ_J

# %%
pfq = catalog.load("pfq_j_dataset")
pfq.head()

# %% [markdown]
# ## Pesticide Use — PUQMEC_J

# %%
puqmec = catalog.load("puqmec_j_dataset")
puqmec.head()

# %% [markdown]
# ## Reproductive Health — RHQ_J

# %%
rhq = catalog.load("rhq_j_dataset")
rhq.head()

# %% [markdown]
# ## Aspirin Use — RXQASA_J

# %%
rxqasa = catalog.load("rxqasa_j_dataset")
rxqasa.head()

# %% [markdown]
# ## Prescription Medications Drug Information — RXQ_DRUG

# %%
rxq_drug = catalog.load("rxq_drug_dataset")
rxq_drug.head()

# %% [markdown]
# ## Prescription Medications — RXQ_RX_J

# %%
rxq_rx = catalog.load("rxq_rx_j_dataset")
rxq_rx.head()

# %% [markdown]
# ## Sleep Disorders — SLQ_J

# %%
slq = catalog.load("slq_j_dataset")
slq.head()

# %% [markdown]
# ## Smoking - Cigarette Use — SMQ_J

# %%
smq = catalog.load("smq_j_dataset")
smq.head()

# %% [markdown]
# ## Smoking - Household Smokers — SMQFAM_J

# %%
smqfam = catalog.load("smqfam_j_dataset")
smqfam.head()

# %% [markdown]
# ## Smoking - Recent Tobacco Use — SMQRTU_J

# %%
smqrtu = catalog.load("smqrtu_j_dataset")
smqrtu.head()

# %% [markdown]
# ## Smoking - Secondhand Smoke Exposure — SMQSHS_J

# %%
smqshs = catalog.load("smqshs_j_dataset")
smqshs.head()

# %% [markdown]
# ## Volatile Toxicant (Questionnaire) — VTQ_J

# %%
vtq = catalog.load("vtq_j_dataset")
vtq.head()

# %% [markdown]
# ## Weight History — WHQ_J

# %%
whq = catalog.load("whq_j_dataset")
whq.head()

# %% [markdown]
# ## Weight History - Youth — WHQMEC_J

# %%
whqmec = catalog.load("whqmec_j_dataset")
whqmec.head()
